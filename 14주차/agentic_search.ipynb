# %%
# libraries
from dotenv import load_dotenv
import requests
import os
from duckduckgo_search import DDGS
from tavily import TavilyClient
from bs4 import BeautifulSoup
import re

# %%
# load environment variables from .env file
_ = load_dotenv()

# %%
# connect
client = TavilyClient(api_key=os.environ.get("TAVILY_API_KEY"))

# %%
# run search
result = client.search("What is in Nvidia's new Blackwell GPU?",
                       include_answer=True)
print(result)
# Out:
# {'query': "What is in Nvidia's new Blackwell GPU?", 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://factory.fpt.ai/ai-insights/what-is-nvidia-blackwell', 'title': 'What is Nvidia Blackwell? Architecture and specs overview', 'content': '# What is Nvidia Blackwell? **What is Nvidia Blackwell,** and why is it being hailed as the engine of the new industrial revolution? By integrating these cutting-edge chips into our sovereign cloud, **FPT AI Factory** enables organizations to stay at the forefront of innovation with high-performance infrastructure tailored for the future of AI. NVIDIA Blackwell refers to a new generation of GPU architecture and data center platform designed primarily for AI and cloud computing workloads. At its core, Blackwell is built to power modern AI use cases, including large-scale model training, real-time inference, and data center operations. *NVIDIA Blackwell refers to a new generation of GPU architecture (Source: FPT AI Factory)*. NVIDIA Blackwell refers to a new generation of GPU architecture. NVIDIA Blackwell is designed to push the boundaries of AI computing, especially for large-scale training and inference. *NVIDIA Blackwell is designed to push the boundaries of AI computing (Source: FPT AI Factory)*. NVIDIA Blackwell is designed to push the boundaries of AI computing.', 'score': 0.7738498, 'raw_content': None}, {'url': 'https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)', 'title': 'Blackwell (microarchitecture) - Wikipedia', 'content': '*   [(Top)](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#). *   [1 History](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#History). *   [2.2 Streaming multiprocessor](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#Streaming_multiprocessor). *   [4 See also](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#See_also). *   [5 References](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#References). *   [Read](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)). *   [Read](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)). "Apple Inc.").[[8]](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_note-8). Veteran semiconductor engineer [Jim Keller](https://en.wikipedia.org/wiki/Jim_Keller_(engineer) "Jim Keller (engineer)"), who had worked on AMD\'s K7, [K12](https://en.wikipedia.org/wiki/AMD_K12 "AMD K12") and [Zen](https://en.wikipedia.org/wiki/Zen_(first_generation) "Zen (first generation)") architectures, criticized this figure and claimed that the same outcome could be achieved for $1 billion through using Ultra Ethernet rather than the proprietary NVLink system.[[23]](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_note-23) The two connected GB100 dies are able to act like a large monolithic piece of silicon with full [cache coherency](https://en.wikipedia.org/wiki/Cache_coherence "Cache coherence") between both dies.[[24]](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_note-24) The dual die package totals 208 billion transistors.[[22]](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_note-Nvidia_2024-03-18-22) Those two GB100 dies are placed on top of a silicon interposer produced using TSMC\'s CoWoS-L 2.5D packaging technique.[[25]](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_note-25). 8.   **[^](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_ref-8)**King, Ian (March 19, 2024). **[^](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_ref-12)**["Nvidia GB200 NVL72"](https://www.nvidia.com/en-us/data-center/gb200-nvl72/). **[^](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_ref-13)**Leswing, Kif (March 18, 2024). **[^](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_ref-20)**Smith, Ryan (March 18, 2024). **[^](https://en.wikipedia.org/wiki/Blackwell_(microarchitecture)#cite_ref-26)**[" ...

# %%
print(result["answer"])
# Out:
# The new Blackwell GPU by Nvidia features 208 billion transistors and is built using a custom TSMC 4NP process, designed for AI and cloud computing workloads.

# %%
city = "San Francisco"

query = f"""
    what is the current weather in {city}?
    Should I travel there today?
    "weather.com"
"""

# %%
ddg = DDGS()
# Out:
# /var/folders/z1/2k144rlj7tsdkm21t8_q3kkm0000gn/T/ipykernel_41489/3423711272.py:1: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   ddg = DDGS()

# %%
def search(query, max_results=6):
    try:
        results = ddg.text(query, max_results=max_results)
        return [i["href"] for i in results]
    except Exception as e:
        print(f"DDG 요청 중 예외 발생으로 이전 결과를 반환합니다.")
        results = [ # cover case where DDG rate limits due to high deeplearning.ai volume
            "https://weather.com/weather/today/l/USCA0987:1:US",
            "https://weather.com/weather/hourbyhour/l/54f9d8baac32496f6b5497b4bf7a277c3e2e6cc5625de69680e6169e7e38e9a8",
        ]
        return results

# %%
for i in search(query):
    print(i)

def scrape_weather_info(url):
    """Scrape content from the given URL"""
    if not url:
        return "Weather information could not be found."
    
    # fetch data
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the webpage."

    # parse result
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup
# Out:
# https://weather.com/en-NA/weather/today/l/San+Francisco+CA+United+States?canonicalCityId=d060bcef6a904af38313393bd51e4c3c
# https://www.accuweather.com/en/us/san-francisco/94103/hourly-weather-forecast/347629
# https://www.theweathernetwork.com/en/city/us/california/san-francisco/current
# https://www.weather-forecast.com/locations/San-Francisco/forecasts/latest
# https://www.weather-us.com/en/california-usa/san-francisco
